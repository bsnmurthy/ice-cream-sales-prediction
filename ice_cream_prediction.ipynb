# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
# Sample dataset
data = {
    'Temperature': [20, 22, 25, 27, 30, 32, 35, 37, 40],
    'IceCreamSales': [100, 120, 150, 170, 200, 230, 270, 300, 340]
}

df = pd.DataFrame(data)
print(df)
# Out:
#    Temperature  IceCreamSales
# 0           20            100
# 1           22            120
# 2           25            150
# 3           27            170
# 4           30            200
# 5           32            230
# 6           35            270
# 7           37            300
# 8           40            340

# %%
plt.scatter(df['Temperature'], df['IceCreamSales'])
plt.xlabel("Temperature (°C)")
plt.ylabel("Ice Cream Sales")
plt.title("Temperature vs Ice Cream Sales")
plt.show()

# %%
X = df[['Temperature']]
y = df['IceCreamSales']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=0
)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print("Slope (m):", model.coef_)
print("Intercept (c):", model.intercept_)
# Out:
# Slope (m): [11.86844614]
# Intercept (c): -144.98570066730235

# %%
y_pred = model.predict(X_test)

print("Actual values:", y_test.values)
print("Predicted values:", y_pred)
# Out:
# Actual values: [300 150]
# Predicted values: [294.14680648 151.72545281]

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error:", mse)
print("R2 Score:", r2)
# Out:
# Mean Squared Error: 18.618530881015026
# R2 Score: 0.9966900389544863

# %%
plt.scatter(X, y)
plt.plot(X, model.predict(X), color='red')
plt.xlabel("Temperature (°C)")
plt.ylabel("Ice Cream Sales")
plt.title("Linear Regression Model")
plt.show()

# %%
temp = [[34]]   # Example temperature
prediction = model.predict(temp)

print("Predicted ice cream sales:", int(prediction[0]))
# Out:
# Predicted ice cream sales: 258
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
